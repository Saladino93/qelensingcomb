# %%
import best

# %%
import matplotlib.pyplot as plt

# %%
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')
plt.rcParams['figure.figsize'] = [12, 8]

# %%
import numpy as np

# %%
import yaml

# %%
import pathlib

# %%
import itertools

# %%
import mystic as my

# %%
values_file = 'configurations/config.yaml' 
with open(values_file, 'r') as stream:
            data = yaml.safe_load(stream)

# %%
estimators_dictionary = data['estimators']
estimators = list(estimators_dictionary.keys())[1:]
estimators
# Out:
# ['shear', 'bh']

# %%
lmin_sel, lmax_sel = data['lmin_sel'], data['lmax_sel']

optversion = data['optversion']

# %%
analysis_directory = data['analysisdirectory']
PP = pathlib.Path(analysis_directory)

# %%
get_dir = lambda s, b: f'h3500s{s}b{b}'

# %%
lista_lmaxes = []
for e in estimators:
    elemento = estimators_dictionary[e]
    lmax_min, lmax_max = elemento['lmax_min'], elemento['lmax_max']
    num = elemento['number']
    lista_lmaxes += [np.linspace(lmax_min, lmax_max, num, dtype = int)]

lmaxes_configs = list(itertools.product(*lista_lmaxes))

# %%
estimators_dictionary = data['estimators']
estimators = list(estimators_dictionary.keys())

# %%
bias_source = 'total'

# %%
PP = pathlib.Path('output1102/')

# %%
noisetag = data['noisekey']
trispectrumtag = data['trispectrumkey']
primarytag = data['primarykey']
secondarytag = data['secondarykey']
primarycrosstag = data['primarycrosskey']

kkkey = data['kkkey']
kgkey = data['kgkey']
ggkey = data['ggkey']
ellskey = data['ellskey']
thetakey = data['thetakey']
thetacrosskey = data['thetacrosskey']

# %%
nu = estimators_dictionary[estimators[0]]['nu']

# %%
totalbiaskey = data['totalbiaskey']

# %%
gtol = 1000
noisebiasconstr = 0
invvariance = 0
fb = 1.

# %%
ns = np.array([])
bs = np.array([])
fs = np.array([])

# %%
for lmaxes in lmaxes_configs:

    s, b = lmaxes
    lmax_directory = get_dir(s, b)
    print('Doing for', lmax_directory)

    P = PP/lmax_directory

    getoutname = lambda key: f'{key}_{nu}.npy'
    noises = np.load(P/getoutname(noisetag))

    getoutname2 = lambda key: f'{key}_total_{nu}.npy'

    if bias_source == 'total':
        biases = np.load(P/'total'/getoutname2(totalbiaskey)) #getoutname('sum_all_totalbias'))
        biasescross = np.load(P/'total'/getoutname2(primarycrosstag)) #/getoutname('sum_all_crosstotalbias'))
    elif bias_source == 'sum_bias':
        biases = np.load(P/getoutname(totalbiaskey))
        biasescross = np.load(P/getoutname(sum_all_crosstotalbias))
    elif bias_source == 'sum_abs_bias':
        biases = np.load(P/getoutname(sumalltotalabsbiaskey))
        biasescross = np.load(P/getoutname(sumallcrosstotalabsbiaskey))

    kg = np.load(P/getoutname(kgkey))
    kk = np.load(P/getoutname(kkkey))
    gg = np.load(P/getoutname(ggkey))
    ells = np.load(P/getoutname(ellskey))
    theta = np.load(P/getoutname(thetakey))
    thetacross = np.load(P/getoutname(thetacrosskey))

    estimators_to_ignore = 'hu_ok'
    Optimizerkk = best.Opt(estimators, lmin_sel, lmax_sel, ells, kk, theta, biases, noises, estimators_to_ignore)
    result = Optimizerkk.optimize(optversion, method = 'diff-ev', gtol = gtol, bounds = [0., 1.], noisebiasconstr = noisebiasconstr, fb = fb, inv_variance = invvariance)

    #result.save_all(pathlib.Path('twocases')/lmax_directory, f'auto_fb_{fb}')
    #result.save(Optimizerkk.biases_selected, pathlib.Path('twocases')/lmax_directory, f'biases') 
    
    fnb_getter = lambda Opt, fb_val: Opt.get_f_n_b(Opt.ells_selected, Opt.theory_selected, Opt.theta_selected, Opt.biases_selected,
                              sum_biases_squared = False, bias_squared = False, fb = fb_val, inv_variance = False)
    
    f, n, b = fnb_getter(Optimizerkk, fb)
    ns = np.append(ns, n(result.x))
    bs = np.append(bs, b(result.x))
    fs = np.append(fs, f(result.x))
# Out:
# Doing for h3500s3000b2500
# Start optimization with diff-ev
# Doing for absbias
# Generation 0 has ChiSquare: 0.001168
# Generation 100 has ChiSquare: 0.000441
# Generation 200 has ChiSquare: 0.000188
# Generation 300 has ChiSquare: 0.000162
# Generation 400 has ChiSquare: 0.000155
# Generation 500 has ChiSquare: 0.000154
# Generation 600 has ChiSquare: 0.000153
# Generation 700 has ChiSquare: 0.000153
# Generation 800 has ChiSquare: 0.000153
# Generation 900 has ChiSquare: 0.000153
# Generation 1000 has ChiSquare: 0.000153
# Generation 1100 has ChiSquare: 0.000153
# Generation 1200 has ChiSquare: 0.000153
# Generation 1300 has ChiSquare: 0.000153
# Generation 1400 has ChiSquare: 0.000153
# Generation 1500 has ChiSquare: 0.000153
# Generation 1600 has ChiSquare: 0.000153
# Generation 1700 has ChiSquare: 0.000153
# Generation 1800 has ChiSquare: 0.000153
# Generation 1900 has ChiSquare: 0.000153
# Generation 2000 has ChiSquare: 0.000153
# Generation 2100 has ChiSquare: 0.000153
# Generation 2200 has ChiSquare: 0.000153
# Generation 2300 has ChiSquare: 0.000153
# Generation 2400 has ChiSquare: 0.000153
# Generation 2500 has ChiSquare: 0.000153
# Generation 2600 has ChiSquare: 0.000153
# Generation 2700 has ChiSquare: 0.000153
# Generation 2800 has ChiSquare: 0.000153
# Generation 2900 has ChiSquare: 0.000153
# STOP("ChangeOverGeneration with {'tolerance': 1e-11, 'generations': 1000}")
# Optimization terminated successfully.
#          Current function value: 0.000153
#          Iterations: 2909
#          Function evaluations: 265667
# Weights in columns [[3.14922129e-08 9.99999969e-01]
#  [1.54885017e-01 8.45114983e-01]
#  [1.58894599e-01 8.41105401e-01]
#  [2.04767939e-01 7.95232061e-01]
#  [8.53221891e-02 9.14677811e-01]
#  [9.99999999e-01 7.08925141e-10]
#  [1.44467909e-10 1.00000000e+00]
#  [3.23172257e-09 9.99999997e-01]]
# Sum [1. 1. 1. 1. 1. 1. 1. 1.]
# Doing for h3500s3000b3000
# Start optimization with diff-ev
# Doing for absbias
# Generation 0 has ChiSquare: 0.000829
# Generation 100 has ChiSquare: 0.000324
# Generation 200 has ChiSquare: 0.000200
# Generation 300 has ChiSquare: 0.000196
# Generation 400 has ChiSquare: 0.000157
# Generation 500 has ChiSquare: 0.000147
# Generation 600 has ChiSquare: 0.000140
# Generation 700 has ChiSquare: 0.000135
# Generation 800 has ChiSquare: 0.000134
# Generation 900 has ChiSquare: 0.000134
# Generation 1000 has ChiSquare: 0.000134
# Generation 1100 has ChiSquare: 0.000134
# Generation 1200 has ChiSquare: 0.000133
# Generation 1300 has ChiSquare: 0.000133
# Generation 1400 has ChiSquare: 0.000133
# Generation 1500 has ChiSquare: 0.000133
# Generation 1600 has ChiSquare: 0.000133
# Generation 1700 has ChiSquare: 0.000133
# Generation 1800 has ChiSquare: 0.000133
# Generation 1900 has ChiSquare: 0.000133
# Generation 2000 has ChiSquare: 0.000133
# Generation 2100 has ChiSquare: 0.000133
# Generation 2200 has ChiSquare: 0.000133
# Generation 2300 has ChiSquare: 0.000133
# Generation 2400 has ChiSquare: 0.000133
# Generation 2500 has ChiSquare: 0.000133
# Generation 2600 has ChiSquare: 0.000133
# Generation 2700 has ChiSquare: 0.000133
# Generation 2800 has ChiSquare: 0.000133
# Generation 2900 has ChiSquare: 0.000133
# Generation 3000 has ChiSquare: 0.000133
# Generation 3100 has ChiSquare: 0.000133
# Generation 3200 has ChiSquare: 0.000133
# Generation 3300 has ChiSquare: 0.000133
# Generation 3400 has ChiSquare: 0.000133
# Generation 3500 has ChiSquare: 0.000133
# Generation 3600 has ChiSquare: 0.000133
# Generation 3700 has ChiSquare: 0.000133
# STOP("ChangeOverGeneration with {'tolerance': 1e-11, 'generations': 1000}")
# Optimization terminated successfully.
#          Current function value: 0.000133
#          Iterations: 3773
#          Function evaluations: 236671
# Weights in columns [[9.99999976e-01 2.44937964e-08]
#  [2.28570838e-01 7.71429162e-01]
#  [5.64803447e-10 9.99999999e-01]
#  [2.24173924e-01 7.75826076e-01]
#  [3.60955374e-09 9.99999996e-01]
#  [3.55169991e-09 9.99999996e-01]
#  [9.99999944e-01 5.59201727e-08]
#  [4.21613032e-01 5.78386968e-01]]
# Sum [1. 1. 1. 1. 1. 1. 1. 1.]
# Doing for h3500s3000b3500
# Start optimization with diff-ev
# Doing for absbias
# Generation 0 has ChiSquare: 0.000827
# Generation 100 has ChiSquare: 0.000380
# Generation 200 has ChiSquare: 0.000302
# Generation 300 has ChiSquare: 0.000238
# Generation 400 has ChiSquare: 0.000200
# Generation 500 has ChiSquare: 0.000180
# Generation 600 has ChiSquare: 0.000180
# Generation 700 has ChiSquare: 0.000168
# Generation 800 has ChiSquare: 0.000153
# Generation 900 has ChiSquare: 0.000151
# Generation 1000 has ChiSquare: 0.000150
# Generation 1100 has ChiSquare: 0.000150
# Generation 1200 has ChiSquare: 0.000149
# Generation 1300 has ChiSquare: 0.000149
# Generation 1400 has ChiSquare: 0.000149
# Generation 1500 has ChiSquare: 0.000149
# Generation 1600 has ChiSquare: 0.000149
# Generation 1700 has ChiSquare: 0.000149
# Generation 1800 has ChiSquare: 0.000149
# Generation 1900 has ChiSquare: 0.000149
# Generation 2000 has ChiSquare: 0.000149
# Generation 2100 has ChiSquare: 0.000149
# Generation 2200 has ChiSquare: 0.000149
# Generation 2300 has ChiSquare: 0.000149
# Generation 2400 has ChiSquare: 0.000149
# Generation 2500 has ChiSquare: 0.000149
# Generation 2600 has ChiSquare: 0.000149
# Generation 2700 has ChiSquare: 0.000149
# Generation 2800 has ChiSquare: 0.000149
# Generation 2900 has ChiSquare: 0.000149
# Generation 3000 has ChiSquare: 0.000149
# Generation 3100 has ChiSquare: 0.000149
# Generation 3200 has ChiSquare: 0.000149
# Generation 3300 has ChiSquare: 0.000149
# Generation 3400 has ChiSquare: 0.000149
# Generation 3500 has ChiSquare: 0.000149
# Generation 3600 has ChiSquare: 0.000149
# Generation 3700 has ChiSquare: 0.000149
# Generation 3800 has ChiSquare: 0.000149
# Generation 3900 has ChiSquare: 0.000149
# Generation 4000 has ChiSquare: 0.000149
# Generation 4100 has ChiSquare: 0.000149
# STOP("ChangeOverGeneration with {'tolerance': 1e-11, 'generations': 1000}")
# Optimization terminated successfully.
#          Current function value: 0.000149
#          Iterations: 4153
#          Function evaluations: 241581
# Weights in columns [[9.99999974e-01 2.63768355e-08]
#  [2.45673085e-07 9.99999754e-01]
#  [3.62906413e-01 6.37093587e-01]
#  [9.99999981e-01 1.91317862e-08]
#  [9.99999990e-01 9.92453408e-09]
#  [9.55387932e-10 9.99999999e-01]
#  [2.04778952e-09 9.99999998e-01]
#  [5.49261364e-01 4.50738636e-01]]
# Sum [1. 1. 1. 1. 1. 1. 1. 1.]
# Doing for h3500s3000b4000
# Start optimization with diff-ev
# Doing for absbias
# Generation 0 has ChiSquare: 0.000817
# Generation 100 has ChiSquare: 0.000265
# Generation 200 has ChiSquare: 0.000215
# Generation 300 has ChiSquare: 0.000204
# Generation 400 has ChiSquare: 0.000189
# Generation 500 has ChiSquare: 0.000189
# Generation 600 has ChiSquare: 0.000180
# Generation 700 has ChiSquare: 0.000177
# Generation 800 has ChiSquare: 0.000176
# Generation 900 has ChiSquare: 0.000176
# Generation 1000 has ChiSquare: 0.000175
# Generation 1100 has ChiSquare: 0.000175
# Generation 1200 has ChiSquare: 0.000175
# Generation 1300 has ChiSquare: 0.000175
# Generation 1400 has ChiSquare: 0.000175
# Generation 1500 has ChiSquare: 0.000175
# Generation 1600 has ChiSquare: 0.000175
# Generation 1700 has ChiSquare: 0.000175
# Generation 1800 has ChiSquare: 0.000175
# Generation 1900 has ChiSquare: 0.000175
# Generation 2000 has ChiSquare: 0.000175
# Generation 2100 has ChiSquare: 0.000175
# Generation 2200 has ChiSquare: 0.000175
# Generation 2300 has ChiSquare: 0.000175
# Generation 2400 has ChiSquare: 0.000175
# Generation 2500 has ChiSquare: 0.000175
# Generation 2600 has ChiSquare: 0.000175
# Generation 2700 has ChiSquare: 0.000175
# Generation 2800 has ChiSquare: 0.000175
# Generation 2900 has ChiSquare: 0.000175
# Generation 3000 has ChiSquare: 0.000175
# Generation 3100 has ChiSquare: 0.000175
# Generation 3200 has ChiSquare: 0.000175
# Generation 3300 has ChiSquare: 0.000175
# Generation 3400 has ChiSquare: 0.000175
# Generation 3500 has ChiSquare: 0.000175
# Generation 3600 has ChiSquare: 0.000175
# Generation 3700 has ChiSquare: 0.000175
# Generation 3800 has ChiSquare: 0.000175
# Generation 3900 has ChiSquare: 0.000175
# STOP("ChangeOverGeneration with {'tolerance': 1e-11, 'generations': 1000}")
# Optimization terminated successfully.
#          Current function value: 0.000175
#          Iterations: 3926
#          Function evaluations: 236018
# Weights in columns [[9.99999997e-01 2.90863655e-09]
#  [9.99999986e-01 1.44461674e-08]
#  [6.41038699e-01 3.58961301e-01]
#  [9.99999997e-01 3.26008009e-09]
#  [9.41710690e-10 9.99999999e-01]
#  [1.12230632e-10 1.00000000e+00]
#  [5.74905082e-10 9.99999999e-01]
#  [5.65008836e-01 4.34991164e-01]]
# Sum [1. 1. 1. 1. 1. 1. 1. 1.]
# Doing for h3500s3000b4500
# Start optimization with diff-ev
# Doing for absbias
# Generation 0 has ChiSquare: 0.000713
# Generation 100 has ChiSquare: 0.000296
# Generation 200 has ChiSquare: 0.000214
# Generation 300 has ChiSquare: 0.000196
# Generation 400 has ChiSquare: 0.000171
# Generation 500 has ChiSquare: 0.000161
# Generation 600 has ChiSquare: 0.000158
# Generation 700 has ChiSquare: 0.000157
# Generation 800 has ChiSquare: 0.000156
# Generation 900 has ChiSquare: 0.000155
# Generation 1000 has ChiSquare: 0.000155
# Generation 1100 has ChiSquare: 0.000155
# Generation 1200 has ChiSquare: 0.000155
# Generation 1300 has ChiSquare: 0.000154
# Generation 1400 has ChiSquare: 0.000154
# Generation 1500 has ChiSquare: 0.000154
# Generation 1600 has ChiSquare: 0.000154
# Generation 1700 has ChiSquare: 0.000154
# Generation 1800 has ChiSquare: 0.000154
# Generation 1900 has ChiSquare: 0.000154
# Generation 2000 has ChiSquare: 0.000154
# Generation 2100 has ChiSquare: 0.000154
# Generation 2200 has ChiSquare: 0.000154
# Generation 2300 has ChiSquare: 0.000154
# Generation 2400 has ChiSquare: 0.000154
# Generation 2500 has ChiSquare: 0.000154
# Generation 2600 has ChiSquare: 0.000154
# Generation 2700 has ChiSquare: 0.000154
# Generation 2800 has ChiSquare: 0.000154
# Generation 2900 has ChiSquare: 0.000154
# Generation 3000 has ChiSquare: 0.000154
# Generation 3100 has ChiSquare: 0.000154
# Generation 3200 has ChiSquare: 0.000154
# Generation 3300 has ChiSquare: 0.000154
# Generation 3400 has ChiSquare: 0.000154
# Generation 3500 has ChiSquare: 0.000154
# Generation 3600 has ChiSquare: 0.000154
# Generation 3700 has ChiSquare: 0.000154
# Generation 3800 has ChiSquare: 0.000154
# Generation 3900 has ChiSquare: 0.000154
# Generation 4000 has ChiSquare: 0.000154
# Generation 4100 has ChiSquare: 0.000154
# Generation 4200 has ChiSquare: 0.000154
# Generation 4300 has ChiSquare: 0.000154
# Generation 4400 has ChiSquare: 0.000154
# Generation 4500 has ChiSquare: 0.000154
# Generation 4600 has ChiSquare: 0.000154
# STOP("ChangeOverGeneration with {'tolerance': 1e-11, 'generations': 1000}")
# Optimization terminated successfully.
#          Current function value: 0.000154
#          Iterations: 4691
#          Function evaluations: 275977
# Weights in columns [[9.99999989e-01 1.05704162e-08]
#  [9.99999997e-01 2.93212365e-09]
#  [7.44840691e-01 2.55159309e-01]
#  [9.99999998e-01 2.32662600e-09]
#  [9.99999998e-01 2.28181574e-09]
#  [5.62235730e-11 1.00000000e+00]
#  [4.14476029e-11 1.00000000e+00]
#  [8.84385044e-03 9.91156150e-01]]
# Sum [1. 1. 1. 1. 1. 1. 1. 1.]
# Doing for h3500s3500b2500
# Start optimization with diff-ev
# Doing for absbias
# Generation 0 has ChiSquare: 0.001061
# Generation 100 has ChiSquare: 0.000325
# Generation 200 has ChiSquare: 0.000240
# Generation 300 has ChiSquare: 0.000181
# Generation 400 has ChiSquare: 0.000163
# Generation 500 has ChiSquare: 0.000163
# Generation 600 has ChiSquare: 0.000144
# Generation 700 has ChiSquare: 0.000141
# Generation 800 has ChiSquare: 0.000139
# Generation 900 has ChiSquare: 0.000138
# Generation 1000 has ChiSquare: 0.000137
# Generation 1100 has ChiSquare: 0.000137
# Generation 1200 has ChiSquare: 0.000137
# Generation 1300 has ChiSquare: 0.000137
# Generation 1400 has ChiSquare: 0.000137
# Generation 1500 has ChiSquare: 0.000137
# Generation 1600 has ChiSquare: 0.000137
# Generation 1700 has ChiSquare: 0.000137
# Generation 1800 has ChiSquare: 0.000137
# Generation 1900 has ChiSquare: 0.000137
# Generation 2000 has ChiSquare: 0.000137
# Generation 2100 has ChiSquare: 0.000137
# Generation 2200 has ChiSquare: 0.000137
# Generation 2300 has ChiSquare: 0.000137
# Generation 2400 has ChiSquare: 0.000137
# Generation 2500 has ChiSquare: 0.000137
# Generation 2600 has ChiSquare: 0.000137
# Generation 2700 has ChiSquare: 0.000137
# Generation 2800 has ChiSquare: 0.000137
# Generation 2900 has ChiSquare: 0.000137
# Generation 3000 has ChiSquare: 0.000137
# Generation 3100 has ChiSquare: 0.000137
# Generation 3200 has ChiSquare: 0.000137
# Generation 3300 has ChiSquare: 0.000137
# Generation 3400 has ChiSquare: 0.000137
# Generation 3500 has ChiSquare: 0.000137
# Generation 3600 has ChiSquare: 0.000137
# Generation 3700 has ChiSquare: 0.000137
# Generation 3800 has ChiSquare: 0.000137
# STOP("ChangeOverGeneration with {'tolerance': 1e-11, 'generations': 1000}")
# Optimization terminated successfully.
#          Current function value: 0.000137
#          Iterations: 3841
#          Function evaluations: 266320
# Weights in columns [[4.85901501e-10 1.00000000e+00]
#  [4.07917470e-01 5.92082530e-01]
#  [2.43174836e-01 7.56825164e-01]
#  [8.99325216e-10 9.99999999e-01]
#  [1.36854812e-09 9.99999999e-01]
#  [9.99999999e-01 5.74211123e-10]
#  [1.00000000e+00 3.99069222e-10]
#  [1.65070476e-08 9.99999983e-01]]
# Sum [1. 1. 1. 1. 1. 1. 1. 1.]
# Doing for h3500s3500b3000
# Start optimization with diff-ev
# Doing for absbias
# Generation 0 has ChiSquare: 0.000851
# Generation 100 has ChiSquare: 0.000306
# Generation 200 has ChiSquare: 0.000229
# Generation 300 has ChiSquare: 0.000209
# Generation 400 has ChiSquare: 0.000167
# Generation 500 has ChiSquare: 0.000135
# Generation 600 has ChiSquare: 0.000133
# Generation 700 has ChiSquare: 0.000127
# Generation 800 has ChiSquare: 0.000125
# Generation 900 has ChiSquare: 0.000125
# Generation 1000 has ChiSquare: 0.000124
# Generation 1100 has ChiSquare: 0.000124
# Generation 1200 has ChiSquare: 0.000124
# Generation 1300 has ChiSquare: 0.000124
# Generation 1400 has ChiSquare: 0.000124
# Generation 1500 has ChiSquare: 0.000124
# Generation 1600 has ChiSquare: 0.000124
# Generation 1700 has ChiSquare: 0.000124
# Generation 1800 has ChiSquare: 0.000124
# Generation 1900 has ChiSquare: 0.000124
# Generation 2000 has ChiSquare: 0.000124
# Generation 2100 has ChiSquare: 0.000124
# Generation 2200 has ChiSquare: 0.000124
# Generation 2300 has ChiSquare: 0.000124
# Generation 2400 has ChiSquare: 0.000124
# Generation 2500 has ChiSquare: 0.000124
# Generation 2600 has ChiSquare: 0.000124
# Generation 2700 has ChiSquare: 0.000124
# Generation 2800 has ChiSquare: 0.000124
# Generation 2900 has ChiSquare: 0.000124
# Generation 3000 has ChiSquare: 0.000124
# Generation 3100 has ChiSquare: 0.000124
# Generation 3200 has ChiSquare: 0.000124
# Generation 3300 has ChiSquare: 0.000124
# Generation 3400 has ChiSquare: 0.000124
# Generation 3500 has ChiSquare: 0.000124
# Generation 3600 has ChiSquare: 0.000124
# Generation 3700 has ChiSquare: 0.000124
# Generation 3800 has ChiSquare: 0.000124
# Generation 3900 has ChiSquare: 0.000124
# Generation 4000 has ChiSquare: 0.000124
# Generation 4100 has ChiSquare: 0.000124
# Generation 4200 has ChiSquare: 0.000124
# Generation 4300 has ChiSquare: 0.000124
# STOP("ChangeOverGeneration with {'tolerance': 1e-11, 'generations': 1000}")
# Optimization terminated successfully.
#          Current function value: 0.000124
#          Iterations: 4357
#          Function evaluations: 218924
# Weights in columns [[4.55025581e-08 9.99999954e-01]
#  [5.80334809e-01 4.19665191e-01]
#  [9.17734126e-10 9.99999999e-01]
#  [1.70291370e-09 9.99999998e-01]
#  [5.88158163e-10 9.99999999e-01]
#  [1.00000000e+00 1.52761137e-11]
#  [9.99999998e-01 2.33984254e-09]
#  [5.83333724e-01 4.16666276e-01]]
# Sum [1. 1. 1. 1. 1. 1. 1. 1.]
# Doing for h3500s3500b3500
# Start optimization with diff-ev
# Doing for absbias
# Generation 0 has ChiSquare: 0.000656
# Generation 100 has ChiSquare: 0.000266
# Generation 200 has ChiSquare: 0.000223
# Generation 300 has ChiSquare: 0.000201
# Generation 400 has ChiSquare: 0.000172
# Generation 500 has ChiSquare: 0.000166
# Generation 600 has ChiSquare: 0.000166
# Generation 700 has ChiSquare: 0.000163
# Generation 800 has ChiSquare: 0.000161
# Generation 900 has ChiSquare: 0.000161
# Generation 1000 has ChiSquare: 0.000160
# Generation 1100 has ChiSquare: 0.000160
# Generation 1200 has ChiSquare: 0.000160
# Generation 1300 has ChiSquare: 0.000160
# Generation 1400 has ChiSquare: 0.000160
# Generation 1500 has ChiSquare: 0.000160
# Generation 1600 has ChiSquare: 0.000160
# Generation 1700 has ChiSquare: 0.000160
# Generation 1800 has ChiSquare: 0.000160
# Generation 1900 has ChiSquare: 0.000160
# Generation 2000 has ChiSquare: 0.000160
# Generation 2100 has ChiSquare: 0.000160
# Generation 2200 has ChiSquare: 0.000160
# Generation 2300 has ChiSquare: 0.000160
# Generation 2400 has ChiSquare: 0.000160
# Generation 2500 has ChiSquare: 0.000160
# Generation 2600 has ChiSquare: 0.000160
# Generation 2700 has ChiSquare: 0.000160
# Generation 2800 has ChiSquare: 0.000160
# Generation 2900 has ChiSquare: 0.000160
# Generation 3000 has ChiSquare: 0.000160
# Generation 3100 has ChiSquare: 0.000160
# Generation 3200 has ChiSquare: 0.000160
# Generation 3300 has ChiSquare: 0.000160
# Generation 3400 has ChiSquare: 0.000160
# Generation 3500 has ChiSquare: 0.000160
# Generation 3600 has ChiSquare: 0.000160
# Generation 3700 has ChiSquare: 0.000160
# Generation 3800 has ChiSquare: 0.000160
# Generation 3900 has ChiSquare: 0.000160
# Generation 4000 has ChiSquare: 0.000160
# Generation 4100 has ChiSquare: 0.000160
# Generation 4200 has ChiSquare: 0.000160
# Generation 4300 has ChiSquare: 0.000160
# Generation 4400 has ChiSquare: 0.000160
# Generation 4500 has ChiSquare: 0.000160
# STOP("ChangeOverGeneration with {'tolerance': 1e-11, 'generations': 1000}")
# Optimization terminated successfully.
#          Current function value: 0.000160
#          Iterations: 4594
#          Function evaluations: 304038
# Weights in columns [[9.34936066e-01 6.50639341e-02]
#  [4.63419251e-01 5.36580749e-01]
#  [6.81388501e-01 3.18611499e-01]
#  [9.99999995e-01 4.76708706e-09]
#  [4.05255617e-10 1.00000000e+00]
#  [6.20196426e-10 9.99999999e-01]
#  [1.98955132e-09 9.99999998e-01]
#  [8.93011203e-01 1.06988797e-01]]
# Sum [1. 1. 1. 1. 1. 1. 1. 1.]
# Doing for h3500s3500b4000
# Start optimization with diff-ev
# Doing for absbias
# Generation 0 has ChiSquare: 0.000645
# Generation 100 has ChiSquare: 0.000261
# Generation 200 has ChiSquare: 0.000236
# Generation 300 has ChiSquare: 0.000187
# Generation 400 has ChiSquare: 0.000182
# Generation 500 has ChiSquare: 0.000179
# Generation 600 has ChiSquare: 0.000177
# Generation 700 has ChiSquare: 0.000175
# Generation 800 has ChiSquare: 0.000174
# Generation 900 has ChiSquare: 0.000174
# Generation 1000 has ChiSquare: 0.000174
# Generation 1100 has ChiSquare: 0.000174
# Generation 1200 has ChiSquare: 0.000174
# Generation 1300 has ChiSquare: 0.000174
# Generation 1400 has ChiSquare: 0.000174
# Generation 1500 has ChiSquare: 0.000174
# Generation 1600 has ChiSquare: 0.000174
# Generation 1700 has ChiSquare: 0.000174
# Generation 1800 has ChiSquare: 0.000174
# Generation 1900 has ChiSquare: 0.000174
# Generation 2000 has ChiSquare: 0.000174
# Generation 2100 has ChiSquare: 0.000174
# Generation 2200 has ChiSquare: 0.000174
# Generation 2300 has ChiSquare: 0.000174
# Generation 2400 has ChiSquare: 0.000174
# Generation 2500 has ChiSquare: 0.000174
# Generation 2600 has ChiSquare: 0.000174
# Generation 2700 has ChiSquare: 0.000174
# Generation 2800 has ChiSquare: 0.000174
# Generation 2900 has ChiSquare: 0.000174
# Generation 3000 has ChiSquare: 0.000174
# Generation 3100 has ChiSquare: 0.000174
# Generation 3200 has ChiSquare: 0.000174
# Generation 3300 has ChiSquare: 0.000174
# Generation 3400 has ChiSquare: 0.000174
# Generation 3500 has ChiSquare: 0.000174
# Generation 3600 has ChiSquare: 0.000174
# Generation 3700 has ChiSquare: 0.000174
# Generation 3800 has ChiSquare: 0.000174
# Generation 3900 has ChiSquare: 0.000174
# Generation 4000 has ChiSquare: 0.000174
# Generation 4100 has ChiSquare: 0.000174
# STOP("ChangeOverGeneration with {'tolerance': 1e-11, 'generations': 1000}")
# Optimization terminated successfully.
#          Current function value: 0.000174
#          Iterations: 4105
#          Function evaluations: 199883
# Weights in columns [[9.97876693e-01 2.12330675e-03]
#  [9.99999992e-01 8.16356449e-09]
#  [9.99999998e-01 2.40862441e-09]
#  [9.99999998e-01 1.60703950e-09]
#  [3.75340595e-09 9.99999996e-01]
#  [1.70176604e-11 1.00000000e+00]
#  [4.26209444e-11 1.00000000e+00]
#  [9.41202744e-01 5.87972556e-02]]
# Sum [1. 1. 1. 1. 1. 1. 1. 1.]
# Doing for h3500s3500b4500
# Start optimization with diff-ev
# Doing for absbias
# Generation 0 has ChiSquare: 0.000972
# Generation 100 has ChiSquare: 0.000376
# Generation 200 has ChiSquare: 0.000300
# Generation 300 has ChiSquare: 0.000227
# Generation 400 has ChiSquare: 0.000214
# Generation 500 has ChiSquare: 0.000201
# Generation 600 has ChiSquare: 0.000198
# Generation 700 has ChiSquare: 0.000192
# Generation 800 has ChiSquare: 0.000189
# Generation 900 has ChiSquare: 0.000188
# Generation 1000 has ChiSquare: 0.000188
# Generation 1100 has ChiSquare: 0.000187
# Generation 1200 has ChiSquare: 0.000187
# Generation 1300 has ChiSquare: 0.000187
# Generation 1400 has ChiSquare: 0.000187
# Generation 1500 has ChiSquare: 0.000187
# Generation 1600 has ChiSquare: 0.000187
# Generation 1700 has ChiSquare: 0.000187
# Generation 1800 has ChiSquare: 0.000187
# Generation 1900 has ChiSquare: 0.000187
# Generation 2000 has ChiSquare: 0.000187
# Generation 2100 has ChiSquare: 0.000187
# Generation 2200 has ChiSquare: 0.000187
# Generation 2300 has ChiSquare: 0.000187
# Generation 2400 has ChiSquare: 0.000187
# Generation 2500 has ChiSquare: 0.000187
# Generation 2600 has ChiSquare: 0.000187
# Generation 2700 has ChiSquare: 0.000187
# Generation 2800 has ChiSquare: 0.000187
# Generation 2900 has ChiSquare: 0.000187
# Generation 3000 has ChiSquare: 0.000187
# Generation 3100 has ChiSquare: 0.000187
# Generation 3200 has ChiSquare: 0.000187
# Generation 3300 has ChiSquare: 0.000187
# Generation 3400 has ChiSquare: 0.000187
# Generation 3500 has ChiSquare: 0.000187
# Generation 3600 has ChiSquare: 0.000187
# Generation 3700 has ChiSquare: 0.000187
# Generation 3800 has ChiSquare: 0.000187
# Generation 3900 has ChiSquare: 0.000187
# Generation 4000 has ChiSquare: 0.000187
# Generation 4100 has ChiSquare: 0.000187
# Generation 4200 has ChiSquare: 0.000187
# Generation 4300 has ChiSquare: 0.000187
# Generation 4400 has ChiSquare: 0.000187
# Generation 4500 has ChiSquare: 0.000187
# STOP("ChangeOverGeneration with {'tolerance': 1e-11, 'generations': 1000}")
# Optimization terminated successfully.
#          Current function value: 0.000187
#          Iterations: 4545
#          Function evaluations: 228503
# Weights in columns [[9.99999991e-01 9.49649115e-09]
#  [9.99999999e-01 8.89764817e-10]
#  [9.99999999e-01 8.07731104e-10]
#  [1.00000000e+00 2.47690091e-10]
#  [2.15357136e-10 1.00000000e+00]
#  [1.00000000e+00 2.28705943e-14]
#  [1.00000000e+00 2.79038126e-10]
#  [4.07756043e-10 1.00000000e+00]]
# Sum [1. 1. 1. 1. 1. 1. 1. 1.]
# Doing for h3500s4000b2500
# Start optimization with diff-ev
# Doing for absbias
# Generation 0 has ChiSquare: 0.001103
# Generation 100 has ChiSquare: 0.000472
# Generation 200 has ChiSquare: 0.000268
# Generation 300 has ChiSquare: 0.000243
# Generation 400 has ChiSquare: 0.000210
# Generation 500 has ChiSquare: 0.000210
# Generation 600 has ChiSquare: 0.000192
# Generation 700 has ChiSquare: 0.000192
# Generation 800 has ChiSquare: 0.000162
# Generation 900 has ChiSquare: 0.000149
# Generation 1000 has ChiSquare: 0.000145
# Generation 1100 has ChiSquare: 0.000143
# Generation 1200 has ChiSquare: 0.000142
# Generation 1300 has ChiSquare: 0.000142
# Generation 1400 has ChiSquare: 0.000142
# Generation 1500 has ChiSquare: 0.000142
# Generation 1600 has ChiSquare: 0.000142
# Generation 1700 has ChiSquare: 0.000142
# Generation 1800 has ChiSquare: 0.000142
# Generation 1900 has ChiSquare: 0.000142
# Generation 2000 has ChiSquare: 0.000142
# Generation 2100 has ChiSquare: 0.000142
# Generation 2200 has ChiSquare: 0.000142
# Generation 2300 has ChiSquare: 0.000142
# Generation 2400 has ChiSquare: 0.000142
# Generation 2500 has ChiSquare: 0.000142
# Generation 2600 has ChiSquare: 0.000142
# Generation 2700 has ChiSquare: 0.000142
# Generation 2800 has ChiSquare: 0.000142
# Generation 2900 has ChiSquare: 0.000142
# Generation 3000 has ChiSquare: 0.000142
# Generation 3100 has ChiSquare: 0.000142
# Generation 3200 has ChiSquare: 0.000142
# Generation 3300 has ChiSquare: 0.000142
# Generation 3400 has ChiSquare: 0.000142
# Generation 3500 has ChiSquare: 0.000142
# Generation 3600 has ChiSquare: 0.000142
# Generation 3700 has ChiSquare: 0.000142
# Generation 3800 has ChiSquare: 0.000142
# Generation 3900 has ChiSquare: 0.000142
# Generation 4000 has ChiSquare: 0.000142
# Generation 4100 has ChiSquare: 0.000142
# Generation 4200 has ChiSquare: 0.000142
# Generation 4300 has ChiSquare: 0.000142
# STOP("ChangeOverGeneration with {'tolerance': 1e-11, 'generations': 1000}")
# Optimization terminated successfully.
#          Current function value: 0.000142
#          Iterations: 4375
#          Function evaluations: 322099
# Weights in columns [[1.06594151e-10 1.00000000e+00]
#  [3.55846556e-01 6.44153444e-01]
#  [2.22589668e-01 7.77410332e-01]
#  [1.27563338e-09 9.99999999e-01]
#  [6.52285643e-10 9.99999999e-01]
#  [9.99999999e-01 5.50677948e-10]
#  [3.61093735e-09 9.99999996e-01]
#  [2.10584204e-08 9.99999979e-01]]
# Sum [1. 1. 1. 1. 1. 1. 1. 1.]
# Doing for h3500s4000b3000
# Start optimization with diff-ev
# Doing for absbias
# Generation 0 has ChiSquare: 0.000891
# Generation 100 has ChiSquare: 0.000398
# Generation 200 has ChiSquare: 0.000220
# Generation 300 has ChiSquare: 0.000176
# Generation 400 has ChiSquare: 0.000147
# Generation 500 has ChiSquare: 0.000139
# Generation 600 has ChiSquare: 0.000139
# Generation 700 has ChiSquare: 0.000135
# Generation 800 has ChiSquare: 0.000133
# Generation 900 has ChiSquare: 0.000133
# Generation 1000 has ChiSquare: 0.000132
# Generation 1100 has ChiSquare: 0.000132
# Generation 1200 has ChiSquare: 0.000132
# Generation 1300 has ChiSquare: 0.000132
# Generation 1400 has ChiSquare: 0.000132
# Generation 1500 has ChiSquare: 0.000132
# Generation 1600 has ChiSquare: 0.000132
# Generation 1700 has ChiSquare: 0.000132
# Generation 1800 has ChiSquare: 0.000132
# Generation 1900 has ChiSquare: 0.000132
# Generation 2000 has ChiSquare: 0.000132
# Generation 2100 has ChiSquare: 0.000132
# Generation 2200 has ChiSquare: 0.000132
# Generation 2300 has ChiSquare: 0.000132
# Generation 2400 has ChiSquare: 0.000132
# Generation 2500 has ChiSquare: 0.000132
# Generation 2600 has ChiSquare: 0.000132
# Generation 2700 has ChiSquare: 0.000132
# Generation 2800 has ChiSquare: 0.000132
# Generation 2900 has ChiSquare: 0.000132
# Generation 3000 has ChiSquare: 0.000132
# Generation 3100 has ChiSquare: 0.000132
# Generation 3200 has ChiSquare: 0.000132
# Generation 3300 has ChiSquare: 0.000132
# Generation 3400 has ChiSquare: 0.000132
# Generation 3500 has ChiSquare: 0.000132
# Generation 3600 has ChiSquare: 0.000132
# Generation 3700 has ChiSquare: 0.000132
# Generation 3800 has ChiSquare: 0.000132
# Generation 3900 has ChiSquare: 0.000132
# Generation 4000 has ChiSquare: 0.000132
# Generation 4100 has ChiSquare: 0.000132
# STOP("ChangeOverGeneration with {'tolerance': 1e-11, 'generations': 1000}")
# Optimization terminated successfully.
#          Current function value: 0.000132
#          Iterations: 4160
#          Function evaluations: 227230
# Weights in columns [[1.01674506e-09 9.99999999e-01]
#  [4.68252383e-01 5.31747617e-01]
#  [1.22651712e-09 9.99999999e-01]
#  [5.90594401e-10 9.99999999e-01]
#  [1.22147395e-10 1.00000000e+00]
#  [6.07144038e-12 1.00000000e+00]
#  [9.99999996e-01 4.48488302e-09]
#  [6.48801658e-01 3.51198342e-01]]
# Sum [1. 1. 1. 1. 1. 1. 1. 1.]
# Doing for h3500s4000b3500
# Start optimization with diff-ev
# Doing for absbias
# Generation 0 has ChiSquare: 0.000661
# Generation 100 has ChiSquare: 0.000278
# Generation 200 has ChiSquare: 0.000211
# Generation 300 has ChiSquare: 0.000160
# Generation 400 has ChiSquare: 0.000160
# Generation 500 has ChiSquare: 0.000160
# Generation 600 has ChiSquare: 0.000155
# Generation 700 has ChiSquare: 0.000154
# Generation 800 has ChiSquare: 0.000154
# Generation 900 has ChiSquare: 0.000153
# Generation 1000 has ChiSquare: 0.000153
# Generation 1100 has ChiSquare: 0.000152
# Generation 1200 has ChiSquare: 0.000152
# Generation 1300 has ChiSquare: 0.000152
# Generation 1400 has ChiSquare: 0.000152
# Generation 1500 has ChiSquare: 0.000152
# Generation 1600 has ChiSquare: 0.000152
# Generation 1700 has ChiSquare: 0.000152
# Generation 1800 has ChiSquare: 0.000152
# Generation 1900 has ChiSquare: 0.000152
# Generation 2000 has ChiSquare: 0.000152
# Generation 2100 has ChiSquare: 0.000152
# Generation 2200 has ChiSquare: 0.000152
# Generation 2300 has ChiSquare: 0.000152
# Generation 2400 has ChiSquare: 0.000152
# Generation 2500 has ChiSquare: 0.000152
# Generation 2600 has ChiSquare: 0.000152
# Generation 2700 has ChiSquare: 0.000152
# Generation 2800 has ChiSquare: 0.000152
# Generation 2900 has ChiSquare: 0.000152
# Generation 3000 has ChiSquare: 0.000152
# Generation 3100 has ChiSquare: 0.000152
# Generation 3200 has ChiSquare: 0.000152
# Generation 3300 has ChiSquare: 0.000152
# Generation 3400 has ChiSquare: 0.000152
# Generation 3500 has ChiSquare: 0.000152
# Generation 3600 has ChiSquare: 0.000152
# Generation 3700 has ChiSquare: 0.000152
# Generation 3800 has ChiSquare: 0.000152
# Generation 3900 has ChiSquare: 0.000152
# Generation 4000 has ChiSquare: 0.000152
# Generation 4100 has ChiSquare: 0.000152
# Generation 4200 has ChiSquare: 0.000152
# STOP("ChangeOverGeneration with {'tolerance': 1e-11, 'generations': 1000}")
# Optimization terminated successfully.
#          Current function value: 0.000152
#          Iterations: 4220
#          Function evaluations: 212315
# Weights in columns [[6.55711975e-01 3.44288025e-01]
#  [3.55484417e-01 6.44515583e-01]
#  [9.99999998e-01 1.92478034e-09]
#  [9.99999998e-01 2.03048123e-09]
#  [7.73648882e-10 9.99999999e-01]
#  [9.18374334e-11 1.00000000e+00]
#  [2.24077423e-10 1.00000000e+00]
#  [9.63673565e-01 3.63264348e-02]]
# Sum [1. 1. 1. 1. 1. 1. 1. 1.]
# Doing for h3500s4000b4000
# Start optimization with diff-ev
# Doing for absbias
# Generation 0 has ChiSquare: 0.000907
# Generation 100 has ChiSquare: 0.000420
# Generation 200 has ChiSquare: 0.000284
# Generation 300 has ChiSquare: 0.000276
# Generation 400 has ChiSquare: 0.000229
# Generation 500 has ChiSquare: 0.000223
# Generation 600 has ChiSquare: 0.000213
# Generation 700 has ChiSquare: 0.000208
# Generation 800 has ChiSquare: 0.000205
# Generation 900 has ChiSquare: 0.000205
# Generation 1000 has ChiSquare: 0.000198
# Generation 1100 has ChiSquare: 0.000193
# Generation 1200 has ChiSquare: 0.000192
# Generation 1300 has ChiSquare: 0.000192
# Generation 1400 has ChiSquare: 0.000191
# Generation 1500 has ChiSquare: 0.000191
# Generation 1600 has ChiSquare: 0.000191
# Generation 1700 has ChiSquare: 0.000190
# Generation 1800 has ChiSquare: 0.000190
# Generation 1900 has ChiSquare: 0.000190
# Generation 2000 has ChiSquare: 0.000190
# Generation 2100 has ChiSquare: 0.000190
# Generation 2200 has ChiSquare: 0.000190
# Generation 2300 has ChiSquare: 0.000190
# Generation 2400 has ChiSquare: 0.000190
# Generation 2500 has ChiSquare: 0.000190
# Generation 2600 has ChiSquare: 0.000190
# Generation 2700 has ChiSquare: 0.000190
# Generation 2800 has ChiSquare: 0.000190
# Generation 2900 has ChiSquare: 0.000190
# Generation 3000 has ChiSquare: 0.000190
# Generation 3100 has ChiSquare: 0.000190
# Generation 3200 has ChiSquare: 0.000190
# Generation 3300 has ChiSquare: 0.000190
# Generation 3400 has ChiSquare: 0.000190
# Generation 3500 has ChiSquare: 0.000190
# Generation 3600 has ChiSquare: 0.000190
# Generation 3700 has ChiSquare: 0.000190
# Generation 3800 has ChiSquare: 0.000190
# Generation 3900 has ChiSquare: 0.000190
# Generation 4000 has ChiSquare: 0.000190
# Generation 4100 has ChiSquare: 0.000190
# Generation 4200 has ChiSquare: 0.000190
# Generation 4300 has ChiSquare: 0.000190
# Generation 4400 has ChiSquare: 0.000190
# STOP("ChangeOverGeneration with {'tolerance': 1e-11, 'generations': 1000}")
# Optimization terminated successfully.
#          Current function value: 0.000190
#          Iterations: 4472
#          Function evaluations: 212811
# Weights in columns [[4.82003953e-01 5.17996047e-01]
#  [8.69509656e-01 1.30490344e-01]
#  [9.99999999e-01 9.19211596e-10]
#  [9.99999999e-01 1.39100864e-09]
#  [5.73094246e-10 9.99999999e-01]
#  [1.00000000e+00 4.57467064e-10]
#  [5.59254840e-10 9.99999999e-01]
#  [8.87636840e-01 1.12363160e-01]]
# Sum [1. 1. 1. 1. 1. 1. 1. 1.]
# Doing for h3500s4000b4500
# Start optimization with diff-ev
# Doing for absbias
# Generation 0 has ChiSquare: 0.000909
# Generation 100 has ChiSquare: 0.000367
# Generation 200 has ChiSquare: 0.000230
# Generation 300 has ChiSquare: 0.000215
# Generation 400 has ChiSquare: 0.000199
# Generation 500 has ChiSquare: 0.000183
# Generation 600 has ChiSquare: 0.000171
# Generation 700 has ChiSquare: 0.000163
# Generation 800 has ChiSquare: 0.000163
# Generation 900 has ChiSquare: 0.000163
# Generation 1000 has ChiSquare: 0.000156
# Generation 1100 has ChiSquare: 0.000155
# Generation 1200 has ChiSquare: 0.000154
# Generation 1300 has ChiSquare: 0.000154
# Generation 1400 has ChiSquare: 0.000153
# Generation 1500 has ChiSquare: 0.000153
# Generation 1600 has ChiSquare: 0.000153
# Generation 1700 has ChiSquare: 0.000153
# Generation 1800 has ChiSquare: 0.000153
# Generation 1900 has ChiSquare: 0.000153
# Generation 2000 has ChiSquare: 0.000153
# Generation 2100 has ChiSquare: 0.000153
# Generation 2200 has ChiSquare: 0.000153
# Generation 2300 has ChiSquare: 0.000153
# Generation 2400 has ChiSquare: 0.000153
# Generation 2500 has ChiSquare: 0.000153
# Generation 2600 has ChiSquare: 0.000153
# Generation 2700 has ChiSquare: 0.000153
# Generation 2800 has ChiSquare: 0.000153
# Generation 2900 has ChiSquare: 0.000153
# Generation 3000 has ChiSquare: 0.000153
# Generation 3100 has ChiSquare: 0.000153
# Generation 3200 has ChiSquare: 0.000153
# Generation 3300 has ChiSquare: 0.000153
# Generation 3400 has ChiSquare: 0.000153
# Generation 3500 has ChiSquare: 0.000153
# Generation 3600 has ChiSquare: 0.000153
# Generation 3700 has ChiSquare: 0.000153
# Generation 3800 has ChiSquare: 0.000153
# Generation 3900 has ChiSquare: 0.000153
# Generation 4000 has ChiSquare: 0.000153
# Generation 4100 has ChiSquare: 0.000153
# Generation 4200 has ChiSquare: 0.000153
# Generation 4300 has ChiSquare: 0.000153
# Generation 4400 has ChiSquare: 0.000153
# Generation 4500 has ChiSquare: 0.000153
# Generation 4600 has ChiSquare: 0.000153
# Generation 4700 has ChiSquare: 0.000153
# Generation 4800 has ChiSquare: 0.000153
# Generation 4900 has ChiSquare: 0.000153
# Generation 5000 has ChiSquare: 0.000153
# Generation 5100 has ChiSquare: 0.000153
# STOP("ChangeOverGeneration with {'tolerance': 1e-11, 'generations': 1000}")
# Optimization terminated successfully.
#          Current function value: 0.000153
#          Iterations: 5104
#          Function evaluations: 242363
# Weights in columns [[9.87292933e-01 1.27070665e-02]
#  [9.99999998e-01 1.59029301e-09]
#  [1.00000000e+00 3.26889404e-10]
#  [1.00000000e+00 2.91424218e-10]
#  [9.99999997e-01 3.41475737e-09]
#  [1.39839458e-10 1.00000000e+00]
#  [6.50463992e-11 1.00000000e+00]
#  [3.14990923e-08 9.99999969e-01]]
# Sum [1. 1. 1. 1. 1. 1. 1. 1.]
# Doing for h3500s4500b2500
# Start optimization with diff-ev
# Doing for absbias
# Generation 0 has ChiSquare: 0.001162
# Generation 100 has ChiSquare: 0.000436
# Generation 200 has ChiSquare: 0.000248
# Generation 300 has ChiSquare: 0.000225
# Generation 400 has ChiSquare: 0.000184
# Generation 500 has ChiSquare: 0.000180
# Generation 600 has ChiSquare: 0.000161
# Generation 700 has ChiSquare: 0.000159
# Generation 800 has ChiSquare: 0.000157
# Generation 900 has ChiSquare: 0.000157
# Generation 1000 has ChiSquare: 0.000157
# Generation 1100 has ChiSquare: 0.000156
# Generation 1200 has ChiSquare: 0.000156
# Generation 1300 has ChiSquare: 0.000156
# Generation 1400 has ChiSquare: 0.000156
# Generation 1500 has ChiSquare: 0.000156
# Generation 1600 has ChiSquare: 0.000156
# Generation 1700 has ChiSquare: 0.000156
# Generation 1800 has ChiSquare: 0.000156
# Generation 1900 has ChiSquare: 0.000156
# Generation 2000 has ChiSquare: 0.000156
# Generation 2100 has ChiSquare: 0.000156
# Generation 2200 has ChiSquare: 0.000156
# Generation 2300 has ChiSquare: 0.000156
# Generation 2400 has ChiSquare: 0.000156
# Generation 2500 has ChiSquare: 0.000156
# Generation 2600 has ChiSquare: 0.000156
# Generation 2700 has ChiSquare: 0.000156
# Generation 2800 has ChiSquare: 0.000156
# Generation 2900 has ChiSquare: 0.000156
# Generation 3000 has ChiSquare: 0.000156
# Generation 3100 has ChiSquare: 0.000156
# Generation 3200 has ChiSquare: 0.000156
# Generation 3300 has ChiSquare: 0.000156
# Generation 3400 has ChiSquare: 0.000156
# Generation 3500 has ChiSquare: 0.000156
# Generation 3600 has ChiSquare: 0.000156
# Generation 3700 has ChiSquare: 0.000156
# Generation 3800 has ChiSquare: 0.000156
# Generation 3900 has ChiSquare: 0.000156
# STOP("ChangeOverGeneration with {'tolerance': 1e-11, 'generations': 1000}")
# Optimization terminated successfully.
#          Current function value: 0.000156
#          Iterations: 3975
#          Function evaluations: 308882
# Weights in columns [[2.30292139e-09 9.99999998e-01]
#  [3.48884128e-01 6.51115872e-01]
#  [2.19566145e-01 7.80433855e-01]
#  [1.27476409e-09 9.99999999e-01]
#  [2.98139491e-10 1.00000000e+00]
#  [8.01614563e-10 9.99999999e-01]
#  [7.87353128e-10 9.99999999e-01]
#  [7.36637845e-10 9.99999999e-01]]
# Sum [1. 1. 1. 1. 1. 1. 1. 1.]
# Doing for h3500s4500b3000
# Start optimization with diff-ev
# Doing for absbias
# Generation 0 has ChiSquare: 0.000896
# Generation 100 has ChiSquare: 0.000409
# Generation 200 has ChiSquare: 0.000187
# Generation 300 has ChiSquare: 0.000145
# Generation 400 has ChiSquare: 0.000140
# Generation 500 has ChiSquare: 0.000137
# Generation 600 has ChiSquare: 0.000135
# Generation 700 has ChiSquare: 0.000134
# Generation 800 has ChiSquare: 0.000134
# Generation 900 has ChiSquare: 0.000133
# Generation 1000 has ChiSquare: 0.000133
# Generation 1100 has ChiSquare: 0.000133
# Generation 1200 has ChiSquare: 0.000133
# Generation 1300 has ChiSquare: 0.000133
# Generation 1400 has ChiSquare: 0.000133
# Generation 1500 has ChiSquare: 0.000133
# Generation 1600 has ChiSquare: 0.000133
# Generation 1700 has ChiSquare: 0.000133
# Generation 1800 has ChiSquare: 0.000133
# Generation 1900 has ChiSquare: 0.000133
# Generation 2000 has ChiSquare: 0.000133
# Generation 2100 has ChiSquare: 0.000133
# Generation 2200 has ChiSquare: 0.000133
# Generation 2300 has ChiSquare: 0.000133
# Generation 2400 has ChiSquare: 0.000133
# Generation 2500 has ChiSquare: 0.000133
# Generation 2600 has ChiSquare: 0.000133
# Generation 2700 has ChiSquare: 0.000133
# Generation 2800 has ChiSquare: 0.000133
# Generation 2900 has ChiSquare: 0.000133
# Generation 3000 has ChiSquare: 0.000133
# Generation 3100 has ChiSquare: 0.000133
# Generation 3200 has ChiSquare: 0.000133
# Generation 3300 has ChiSquare: 0.000133
# Generation 3400 has ChiSquare: 0.000133
# Generation 3500 has ChiSquare: 0.000133
# Generation 3600 has ChiSquare: 0.000133
# Generation 3700 has ChiSquare: 0.000133
# STOP("ChangeOverGeneration with {'tolerance': 1e-11, 'generations': 1000}")
# Optimization terminated successfully.
#          Current function value: 0.000133
#          Iterations: 3732
#          Function evaluations: 182041
# Weights in columns [[9.04848556e-09 9.99999991e-01]
#  [4.40199504e-01 5.59800496e-01]
#  [1.32001231e-09 9.99999999e-01]
#  [2.25460603e-11 1.00000000e+00]
#  [3.43375145e-10 1.00000000e+00]
#  [1.93225019e-10 1.00000000e+00]
#  [1.93065297e-02 9.80693470e-01]
#  [4.84653427e-01 5.15346573e-01]]
# Sum [1. 1. 1. 1. 1. 1. 1. 1.]
# Doing for h3500s4500b3500
# Start optimization with diff-ev
# Doing for absbias
# Generation 0 has ChiSquare: 0.001072
# Generation 100 has ChiSquare: 0.000270
# Generation 200 has ChiSquare: 0.000217
# Generation 300 has ChiSquare: 0.000193
# Generation 400 has ChiSquare: 0.000179
# Generation 500 has ChiSquare: 0.000172
# Generation 600 has ChiSquare: 0.000165
# Generation 700 has ChiSquare: 0.000159
# Generation 800 has ChiSquare: 0.000159
# Generation 900 has ChiSquare: 0.000157
# Generation 1000 has ChiSquare: 0.000157
# Generation 1100 has ChiSquare: 0.000156
# Generation 1200 has ChiSquare: 0.000156
# Generation 1300 has ChiSquare: 0.000156
# Generation 1400 has ChiSquare: 0.000156
# Generation 1500 has ChiSquare: 0.000156
# Generation 1600 has ChiSquare: 0.000156
# Generation 1700 has ChiSquare: 0.000156
# Generation 1800 has ChiSquare: 0.000156
# Generation 1900 has ChiSquare: 0.000155
# Generation 2000 has ChiSquare: 0.000155
# Generation 2100 has ChiSquare: 0.000155
# Generation 2200 has ChiSquare: 0.000155
# Generation 2300 has ChiSquare: 0.000155
# Generation 2400 has ChiSquare: 0.000155
# Generation 2500 has ChiSquare: 0.000155
# Generation 2600 has ChiSquare: 0.000155
# Generation 2700 has ChiSquare: 0.000155
# Generation 2800 has ChiSquare: 0.000155
# Generation 2900 has ChiSquare: 0.000155
# Generation 3000 has ChiSquare: 0.000155
# Generation 3100 has ChiSquare: 0.000155
# Generation 3200 has ChiSquare: 0.000155
# Generation 3300 has ChiSquare: 0.000155
# Generation 3400 has ChiSquare: 0.000155
# Generation 3500 has ChiSquare: 0.000155
# Generation 3600 has ChiSquare: 0.000155
# Generation 3700 has ChiSquare: 0.000155
# Generation 3800 has ChiSquare: 0.000155
# Generation 3900 has ChiSquare: 0.000155
# Generation 4000 has ChiSquare: 0.000155
# Generation 4100 has ChiSquare: 0.000155
# Generation 4200 has ChiSquare: 0.000155
# Generation 4300 has ChiSquare: 0.000155
# Generation 4400 has ChiSquare: 0.000155
# STOP("ChangeOverGeneration with {'tolerance': 1e-11, 'generations': 1000}")
# Optimization terminated successfully.
#          Current function value: 0.000155
#          Iterations: 4420
#          Function evaluations: 205802
# Weights in columns [[5.79360998e-02 9.42063900e-01]
#  [3.44494954e-01 6.55505046e-01]
#  [9.99999999e-01 1.20894428e-09]
#  [1.00000000e+00 1.59182001e-10]
#  [2.98282239e-10 1.00000000e+00]
#  [8.92767890e-12 1.00000000e+00]
#  [2.17456741e-10 1.00000000e+00]
#  [6.04987095e-02 9.39501290e-01]]
# Sum [1. 1. 1. 1. 1. 1. 1. 1.]
# Doing for h3500s4500b4000
# Start optimization with diff-ev
# Doing for absbias
# Generation 0 has ChiSquare: 0.001028
# Generation 100 has ChiSquare: 0.000576
# Generation 200 has ChiSquare: 0.000417
# Generation 300 has ChiSquare: 0.000327
# Generation 400 has ChiSquare: 0.000251
# Generation 500 has ChiSquare: 0.000244
# Generation 600 has ChiSquare: 0.000229
# Generation 700 has ChiSquare: 0.000218
# Generation 800 has ChiSquare: 0.000196
# Generation 900 has ChiSquare: 0.000175
# Generation 1000 has ChiSquare: 0.000175
# Generation 1100 has ChiSquare: 0.000173
# Generation 1200 has ChiSquare: 0.000173
# Generation 1300 has ChiSquare: 0.000173
# Generation 1400 has ChiSquare: 0.000172
# Generation 1500 has ChiSquare: 0.000172
# Generation 1600 has ChiSquare: 0.000171
# Generation 1700 has ChiSquare: 0.000171
# Generation 1800 has ChiSquare: 0.000171
# Generation 1900 has ChiSquare: 0.000171
# Generation 2000 has ChiSquare: 0.000171
# Generation 2100 has ChiSquare: 0.000171
# Generation 2200 has ChiSquare: 0.000171
# Generation 2300 has ChiSquare: 0.000171
# Generation 2400 has ChiSquare: 0.000171
# Generation 2500 has ChiSquare: 0.000171
# Generation 2600 has ChiSquare: 0.000171
# Generation 2700 has ChiSquare: 0.000171
# Generation 2800 has ChiSquare: 0.000171
# Generation 2900 has ChiSquare: 0.000171
# Generation 3000 has ChiSquare: 0.000171
# Generation 3100 has ChiSquare: 0.000171
# Generation 3200 has ChiSquare: 0.000171
# Generation 3300 has ChiSquare: 0.000171
# Generation 3400 has ChiSquare: 0.000171
# Generation 3500 has ChiSquare: 0.000171
# Generation 3600 has ChiSquare: 0.000171
# Generation 3700 has ChiSquare: 0.000171
# Generation 3800 has ChiSquare: 0.000171
# Generation 3900 has ChiSquare: 0.000171
# Generation 4000 has ChiSquare: 0.000171
# Generation 4100 has ChiSquare: 0.000171
# Generation 4200 has ChiSquare: 0.000171
# STOP("ChangeOverGeneration with {'tolerance': 1e-11, 'generations': 1000}")
# Optimization terminated successfully.
#          Current function value: 0.000171
#          Iterations: 4297
#          Function evaluations: 192824
# Weights in columns [[7.93186187e-01 2.06813813e-01]
#  [8.91481706e-01 1.08518294e-01]
#  [9.99999999e-01 5.67555669e-10]
#  [9.99999994e-01 6.11428219e-09]
#  [4.22921080e-09 9.99999996e-01]
#  [4.75928767e-10 1.00000000e+00]
#  [3.02510462e-09 9.99999997e-01]
#  [1.00704546e-01 8.99295454e-01]]
# Sum [1. 1. 1. 1. 1. 1. 1. 1.]
# Doing for h3500s4500b4500
# Start optimization with diff-ev
# Doing for absbias
# Generation 0 has ChiSquare: 0.001080
# Generation 100 has ChiSquare: 0.000349
# Generation 200 has ChiSquare: 0.000268
# Generation 300 has ChiSquare: 0.000216
# Generation 400 has ChiSquare: 0.000202
# Generation 500 has ChiSquare: 0.000197
# Generation 600 has ChiSquare: 0.000167
# Generation 700 has ChiSquare: 0.000166
# Generation 800 has ChiSquare: 0.000160
# Generation 900 has ChiSquare: 0.000160
# Generation 1000 has ChiSquare: 0.000158
# Generation 1100 has ChiSquare: 0.000158
# Generation 1200 has ChiSquare: 0.000157
# Generation 1300 has ChiSquare: 0.000156
# Generation 1400 has ChiSquare: 0.000156
# Generation 1500 has ChiSquare: 0.000156
# Generation 1600 has ChiSquare: 0.000156
# Generation 1700 has ChiSquare: 0.000156
# Generation 1800 has ChiSquare: 0.000156
# Generation 1900 has ChiSquare: 0.000156
# Generation 2000 has ChiSquare: 0.000156
# Generation 2100 has ChiSquare: 0.000156
# Generation 2200 has ChiSquare: 0.000156
# Generation 2300 has ChiSquare: 0.000156
# Generation 2400 has ChiSquare: 0.000156
# Generation 2500 has ChiSquare: 0.000156
# Generation 2600 has ChiSquare: 0.000156
# Generation 2700 has ChiSquare: 0.000156
# Generation 2800 has ChiSquare: 0.000156
# Generation 2900 has ChiSquare: 0.000156
# Generation 3000 has ChiSquare: 0.000156
# Generation 3100 has ChiSquare: 0.000156
# Generation 3200 has ChiSquare: 0.000156
# Generation 3300 has ChiSquare: 0.000156
# Generation 3400 has ChiSquare: 0.000156
# Generation 3500 has ChiSquare: 0.000156
# Generation 3600 has ChiSquare: 0.000156
# Generation 3700 has ChiSquare: 0.000156
# Generation 3800 has ChiSquare: 0.000156
# Generation 3900 has ChiSquare: 0.000156
# Generation 4000 has ChiSquare: 0.000156
# Generation 4100 has ChiSquare: 0.000156
# Generation 4200 has ChiSquare: 0.000156
# Generation 4300 has ChiSquare: 0.000156
# Generation 4400 has ChiSquare: 0.000156
# Generation 4500 has ChiSquare: 0.000156
# Generation 4600 has ChiSquare: 0.000156
# Generation 4700 has ChiSquare: 0.000156
# Generation 4800 has ChiSquare: 0.000156
# Generation 4900 has ChiSquare: 0.000156
# Generation 5000 has ChiSquare: 0.000156
# Generation 5100 has ChiSquare: 0.000156
# STOP("ChangeOverGeneration with {'tolerance': 1e-11, 'generations': 1000}")
# Optimization terminated successfully.
#          Current function value: 0.000156
#          Iterations: 5179
#          Function evaluations: 230550
# Weights in columns [[2.74709724e-01 7.25290276e-01]
#  [9.99999999e-01 5.14696175e-10]
#  [9.99999999e-01 6.06825146e-10]
#  [1.00000000e+00 2.85864554e-10]
#  [8.57342266e-10 9.99999999e-01]
#  [9.48771436e-11 1.00000000e+00]
#  [1.26124578e-11 1.00000000e+00]
#  [3.87850154e-02 9.61214985e-01]]
# Sum [1. 1. 1. 1. 1. 1. 1. 1.]

# %%
best_config = lmaxes_configs[list(fs).index(min(list(fs)))]

# %%
for lmaxes in [best_config]:

    s, b = lmaxes
    lmax_directory = get_dir(s, b)
    print('Doing for', lmax_directory)

    P = PP/lmax_directory

    getoutname = lambda key: f'{key}_{nu}.npy'
    noises = np.load(P/getoutname(noisetag))

    getoutname2 = lambda key: f'{key}_total_{nu}.npy'

    if bias_source == 'total':
        biases = np.load(P/'total'/getoutname2(totalbiaskey)) #getoutname('sum_all_totalbias'))
        biasescross = np.load(P/'total'/getoutname2(primarycrosstag)) #/getoutname('sum_all_crosstotalbias'))
    elif bias_source == 'sum_bias':
        biases = np.load(P/getoutname(totalbiaskey))
        biasescross = np.load(P/getoutname(sum_all_crosstotalbias))
    elif bias_source == 'sum_abs_bias':
        biases = np.load(P/getoutname(sumalltotalabsbiaskey))
        biasescross = np.load(P/getoutname(sumallcrosstotalabsbiaskey))

    kg = np.load(P/getoutname(kgkey))
    kk = np.load(P/getoutname(kkkey))
    gg = np.load(P/getoutname(ggkey))
    ells = np.load(P/getoutname(ellskey))
    theta = np.load(P/getoutname(thetakey))
    thetacross = np.load(P/getoutname(thetacrosskey))

    estimators_to_ignore = 'hu_ok'
    Optimizerkk = best.Opt(estimators, lmin_sel, lmax_sel, ells, kk, theta, biases, noises, estimators_to_ignore)
    result = Optimizerkk.optimize(optversion, method = 'diff-ev', gtol = gtol, bounds = [0., 1.], noisebiasconstr = noisebiasconstr, fb = fb, inv_variance = invvariance)

    #result.save_all(pathlib.Path('twocases')/lmax_directory, f'auto_fb_{fb}')
    #result.save(Optimizerkk.biases_selected, pathlib.Path('twocases')/lmax_directory, f'biases') 
    
    fnb_getter = lambda Opt, fb_val: Opt.get_f_n_b(Opt.ells_selected, Opt.theory_selected, Opt.theta_selected, Opt.biases_selected,
                              sum_biases_squared = False, bias_squared = False, fb = fb_val, inv_variance = False)
    
    f, n, b = fnb_getter(Optimizerkk, fb)
# Out:
# Doing for h3500s3500b3000
# Start optimization with diff-ev
# Doing for absbias
# Generation 0 has ChiSquare: 0.000846
# Generation 100 has ChiSquare: 0.000317
# Generation 200 has ChiSquare: 0.000180
# Generation 300 has ChiSquare: 0.000162
# Generation 400 has ChiSquare: 0.000152
# Generation 500 has ChiSquare: 0.000137
# Generation 600 has ChiSquare: 0.000133
# Generation 700 has ChiSquare: 0.000131
# Generation 800 has ChiSquare: 0.000130
# Generation 900 has ChiSquare: 0.000129
# Generation 1000 has ChiSquare: 0.000129
# Generation 1100 has ChiSquare: 0.000129
# Generation 1200 has ChiSquare: 0.000129
# Generation 1300 has ChiSquare: 0.000129
# Generation 1400 has ChiSquare: 0.000129
# Generation 1500 has ChiSquare: 0.000129
# Generation 1600 has ChiSquare: 0.000129
# Generation 1700 has ChiSquare: 0.000129
# Generation 1800 has ChiSquare: 0.000129
# Generation 1900 has ChiSquare: 0.000129
# Generation 2000 has ChiSquare: 0.000129
# Generation 2100 has ChiSquare: 0.000129
# Generation 2200 has ChiSquare: 0.000129
# Generation 2300 has ChiSquare: 0.000129
# Generation 2400 has ChiSquare: 0.000129
# Generation 2500 has ChiSquare: 0.000129
# Generation 2600 has ChiSquare: 0.000129
# Generation 2700 has ChiSquare: 0.000129
# Generation 2800 has ChiSquare: 0.000129
# Generation 2900 has ChiSquare: 0.000129
# Generation 3000 has ChiSquare: 0.000129
# Generation 3100 has ChiSquare: 0.000129
# Generation 3200 has ChiSquare: 0.000129
# Generation 3300 has ChiSquare: 0.000129
# Generation 3400 has ChiSquare: 0.000129
# Generation 3500 has ChiSquare: 0.000129
# Generation 3600 has ChiSquare: 0.000129
# Generation 3700 has ChiSquare: 0.000129
# Generation 3800 has ChiSquare: 0.000129
# Generation 3900 has ChiSquare: 0.000129
# Generation 4000 has ChiSquare: 0.000129
# Generation 4100 has ChiSquare: 0.000129
# Generation 4200 has ChiSquare: 0.000129
# Generation 4300 has ChiSquare: 0.000129
# STOP("ChangeOverGeneration with {'tolerance': 1e-11, 'generations': 1000}")
# Optimization terminated successfully.
#          Current function value: 0.000129
#          Iterations: 4390
#          Function evaluations: 265767
# Weights in columns [[1.33381785e-08 9.99999987e-01]
#  [6.50840305e-01 3.49159695e-01]
#  [1.19635118e-08 9.99999988e-01]
#  [4.82100468e-10 1.00000000e+00]
#  [2.92494006e-11 1.00000000e+00]
#  [1.76627395e-09 9.99999998e-01]
#  [9.99999999e-01 1.14745358e-09]
#  [2.56486642e-01 7.43513358e-01]]
# Sum [1. 1. 1. 1. 1. 1. 1. 1.]

# %%
n(result.x)
b(result.x)
f(result.x)
# Out:
# 0.00012773079427518517

# %%
min(fs)
# Out:
# 0.00012343079133963526

# %%
b = Optimizerkk.biases_selected
n = Optimizerkk.noises_selected

# %%
result.ws
# Out:
# (array([1.33381785e-08, 6.50840305e-01, 1.19635118e-08, 4.82100468e-10,
#         2.92494006e-11, 1.76627395e-09, 9.99999999e-01, 2.56486642e-01]),
#  array([9.99999987e-01, 3.49159695e-01, 9.99999988e-01, 1.00000000e+00,
#         1.00000000e+00, 9.99999998e-01, 1.14745358e-09, 7.43513358e-01]),
#  array([7.68557245e-06, 2.10010856e-05, 2.24713837e-05, 8.44628560e-06,
#         3.82915584e-06, 1.41152438e-06, 1.96797405e-07, 1.70654035e-16]))

# %%
ws, wbh, w = result.ws

# %%
a = np.c_[ws, wbh]
    
combinedn = Optimizerkk.get_bias_part(a, Optimizerkk.noises_selected)
combinedb = Optimizerkk.get_bias_part(a, Optimizerkk.biases_selected)

# %%
fig, ax = plt.subplots(nrows = 5, sharex = True)

kk = Optimizerkk.theory_selected

ells = Optimizerkk.ells_selected

ax[0].plot(ells, combinedb/kk, color = 'purple', label = 'Combined', marker = 'o')
ax[0].plot(ells, b[0, 0]/kk, color = 'red', label = 'S')
ax[0].plot(ells, b[1, 1]/kk, color = 'green', label = 'B')

ax[1].plot(ells, combinedn, color = 'purple', label = 'Combined', marker = 'o')
ax[1].plot(ells, n[0, 0], color = 'red', label = 'S')
ax[1].plot(ells, n[1, 1], color = 'green', label = 'B')


ax[2].plot(ells, ws, color = 'red', label = 'S')
ax[2].plot(ells, wbh, color = 'green', label = 'B')

ax[3].plot(ells, w, color = 'black')

ax[4].plot(ells, ws*w*ells, color = 'red', label = 'S')
ax[4].plot(ells, wbh*w*ells, color = 'green', label = 'B')

ax[4].set_xlabel('$L$')
ax[0].set_ylabel('$B$')
ax[1].set_ylabel('$N$')
ax[2].set_ylabel('$W$')
ax[3].set_ylabel('$W_L$')
ax[4].set_ylabel('$LWW_L$')
ax[0].set_xscale('log')
ax[0].legend(ncol = 4)

# %%
for lmaxes in [lmaxes_configs[0]]:

    s, b = lmaxes
    lmax_directory = get_dir(s, b)
    print('Doing for', lmax_directory)

    P = PP/lmax_directory

    getoutname = lambda key: f'{key}_{nu}.npy'
    noises = np.load(P/getoutname(noisetag))

    getoutname2 = lambda key: f'{key}_total_{nu}.npy'

    if bias_source == 'total':
        biases = np.load(P/'total'/getoutname2(totalbiaskey)) #getoutname('sum_all_totalbias'))
        biasescross = np.load(P/'total'/getoutname2(primarycrosstag)) #/getoutname('sum_all_crosstotalbias'))
    elif bias_source == 'sum_bias':
        biases = np.load(P/getoutname(totalbiaskey))
        biasescross = np.load(P/getoutname(sum_all_crosstotalbias))
    elif bias_source == 'sum_abs_bias':
        biases = np.load(P/getoutname(sumalltotalabsbiaskey))
        biasescross = np.load(P/getoutname(sumallcrosstotalabsbiaskey))

    kg = np.load(P/getoutname(kgkey))
    kk = np.load(P/getoutname(kkkey))
    gg = np.load(P/getoutname(ggkey))
    ells = np.load(P/getoutname(ellskey))
    theta = np.load(P/getoutname(thetakey))
    thetacross = np.load(P/getoutname(thetacrosskey))

    estimators_to_ignore = 'hu_ok'
    Optimizerkk = best.Opt(estimators, lmin_sel, lmax_sel, ells, kk, theta, biases, noises, estimators_to_ignore)
    result = Optimizerkk.optimize(optversion, method = 'diff-ev', gtol = gtol, bounds = [0., 1.], noisebiasconstr = noisebiasconstr, fb = fb, inv_variance = invvariance)

    #result.save_all(pathlib.Path('twocases')/lmax_directory, f'auto_fb_{fb}')
    #result.save(Optimizerkk.biases_selected, pathlib.Path('twocases')/lmax_directory, f'biases') 
    
    fnb_getter = lambda Opt, fb_val: Opt.get_f_n_b(Opt.ells_selected, Opt.theory_selected, Opt.theta_selected, Opt.biases_selected,
                              sum_biases_squared = False, bias_squared = False, fb = fb_val, inv_variance = False)
    
    f, n, b = fnb_getter(Optimizerkk, fb)
    ns = np.append(ns, n(result.x))
    bs = np.append(bs, b(result.x))
    fs = np.append(fs, f(result.x))
# Out:
# Doing for h3500s3000b2500
# Start optimization with diff-ev
# Doing for absbias
# Generation 0 has ChiSquare: 0.001034
# Generation 100 has ChiSquare: 0.000445
# Generation 200 has ChiSquare: 0.000277
# Generation 300 has ChiSquare: 0.000197
# Generation 400 has ChiSquare: 0.000163
# Generation 500 has ChiSquare: 0.000159
# Generation 600 has ChiSquare: 0.000154
# Generation 700 has ChiSquare: 0.000153
# Generation 800 has ChiSquare: 0.000153
# Generation 900 has ChiSquare: 0.000153
# Generation 1000 has ChiSquare: 0.000153
# Generation 1100 has ChiSquare: 0.000153
# Generation 1200 has ChiSquare: 0.000153
# Generation 1300 has ChiSquare: 0.000153
# Generation 1400 has ChiSquare: 0.000153
# Generation 1500 has ChiSquare: 0.000153
# Generation 1600 has ChiSquare: 0.000153
# Generation 1700 has ChiSquare: 0.000153
# Generation 1800 has ChiSquare: 0.000153
# Generation 1900 has ChiSquare: 0.000153
# Generation 2000 has ChiSquare: 0.000153
# Generation 2100 has ChiSquare: 0.000153
# Generation 2200 has ChiSquare: 0.000153
# Generation 2300 has ChiSquare: 0.000153
# Generation 2400 has ChiSquare: 0.000153
# Generation 2500 has ChiSquare: 0.000153
# Generation 2600 has ChiSquare: 0.000153
# Generation 2700 has ChiSquare: 0.000153
# Generation 2800 has ChiSquare: 0.000153
# Generation 2900 has ChiSquare: 0.000153
# Generation 3000 has ChiSquare: 0.000153
# Generation 3100 has ChiSquare: 0.000153
# Generation 3200 has ChiSquare: 0.000153
# Generation 3300 has ChiSquare: 0.000153
# Generation 3400 has ChiSquare: 0.000153
# STOP("ChangeOverGeneration with {'tolerance': 1e-11, 'generations': 1000}")
# Optimization terminated successfully.
#          Current function value: 0.000153
#          Iterations: 3463
#          Function evaluations: 357486
# Weights in columns [[2.01986240e-08 9.99999980e-01]
#  [1.54876431e-01 8.45123569e-01]
#  [1.58900466e-01 8.41099534e-01]
#  [2.04768507e-01 7.95231493e-01]
#  [8.53207140e-02 9.14679286e-01]
#  [9.99999999e-01 1.09920073e-09]
#  [1.43617163e-09 9.99999999e-01]
#  [2.43230039e-09 9.99999998e-01]]
# Sum [1. 1. 1. 1. 1. 1. 1. 1.]

# %%
ws, wbh, w = result.ws

a = np.c_[ws, wbh]
    
combinedn = Optimizerkk.get_bias_part(a, Optimizerkk.noises_selected)
combinedb = Optimizerkk.get_bias_part(a, Optimizerkk.biases_selected)

# %%
combinedb_ = Optimizerkk.get_bias_part(a, abs(Optimizerkk.biases_selected))

# %%
combinedtheta2 = np.einsum('ijkm..., ...i, ...j, ...k, ...m -> ...', Optimizerkk.theta_selected, a, a, a, a)

# %%
kk = Optimizerkk.theory_selected

# %%
denA = Optimizerkk.integerate_discrete(kk**2/combinedtheta2, Optimizerkk.ells_selected)
denB = Optimizerkk.integerate_discrete(kk*combinedb_/combinedtheta2, Optimizerkk.ells_selected)
den = denA-fb*denB**2/(1+fb*denB)
num = 1-fb*(combinedb_/kk)*(denB/(1+fb*denB))

# %%
num/den
# Out:
# array([0.0001233 , 0.00012397, 0.00012411, 0.00012383, 0.00012341,
#        0.00012368, 0.00012252, 0.00012169])

# %%
w_analytical_mv = kk**2/combinedtheta2/denA
w_analytical = w_analytical_mv*(num/den)*denA

# %%
w_analytical/w_analytical_mv
# Out:
# array([0.99748397, 1.00285421, 1.00405269, 1.00176457, 0.99838476,
#        1.00051497, 0.991195  , 0.98448693])

# %%
Optimizerkk.integerate_discrete(w_analytical, Optimizerkk.ells_selected)
# Out:
# 1.0

# %%
plt.plot(Optimizerkk.ells_selected, w_analytical_mv, color = 'black', ls = ':', label = 'Analytical MV')
plt.plot(Optimizerkk.ells_selected, w_analytical, color = 'black', ls = '--', label = 'Analytical')
plt.plot(Optimizerkk.ells_selected, w, color = 'black')
plt.legend()

# %%
b = Optimizerkk.biases_selected
n = Optimizerkk.noises_selected

# %%
fig, ax = plt.subplots(nrows = 5, sharex = True)

kk = Optimizerkk.theory_selected

ells = Optimizerkk.ells_selected

ax[0].plot(ells, combinedb/kk, color = 'purple', label = 'Combined', marker = 'o')
ax[0].plot(ells, b[0, 0]/kk, color = 'red', label = 'S')
ax[0].plot(ells, b[1, 1]/kk, color = 'green', label = 'B')

ax[1].plot(ells, combinedn, color = 'purple', label = 'Combined', marker = 'o')
ax[1].plot(ells, n[0, 0], color = 'red', label = 'S')
ax[1].plot(ells, n[1, 1], color = 'green', label = 'B')


ax[2].plot(ells, ws, color = 'red', label = 'S')
ax[2].plot(ells, wbh, color = 'green', label = 'B')

ax[3].plot(ells, w, color = 'black')

ax[4].plot(ells, ws*w*ells, color = 'red', label = 'S')
ax[4].plot(ells, wbh*w*ells, color = 'green', label = 'B')

ax[4].set_xlabel('$L$')
ax[0].set_ylabel('$B$')
ax[1].set_ylabel('$N$')
ax[2].set_ylabel('$W$')
ax[3].set_ylabel('$W_L$')
ax[4].set_ylabel('$LWW_L$')
ax[0].set_xscale('log')
ax[0].legend(ncol = 4)

# %%
for lmaxes in [lmaxes_configs[0]]:

    s, b = lmaxes
    lmax_directory = get_dir(s, b)
    print('Doing for', lmax_directory)

    P = PP/lmax_directory

    getoutname = lambda key: f'{key}_{nu}.npy'
    noises = np.load(P/getoutname(noisetag))

    getoutname2 = lambda key: f'{key}_total_{nu}.npy'

    if bias_source == 'total':
        biases = np.load(P/'total'/getoutname2(totalbiaskey)) #getoutname('sum_all_totalbias'))
        biasescross = np.load(P/'total'/getoutname2(primarycrosstag)) #/getoutname('sum_all_crosstotalbias'))
    elif bias_source == 'sum_bias':
        biases = np.load(P/getoutname(totalbiaskey))
        biasescross = np.load(P/getoutname(sum_all_crosstotalbias))
    elif bias_source == 'sum_abs_bias':
        biases = np.load(P/getoutname(sumalltotalabsbiaskey))
        biasescross = np.load(P/getoutname(sumallcrosstotalabsbiaskey))

    kg = np.load(P/getoutname(kgkey))
    kk = np.load(P/getoutname(kkkey))
    gg = np.load(P/getoutname(ggkey))
    ells = np.load(P/getoutname(ellskey))
    theta = np.load(P/getoutname(thetakey))
    thetacross = np.load(P/getoutname(thetacrosskey))

    estimators_to_ignore = 'hu_ok'
    Optimizerkk = best.Opt(estimators, lmin_sel, lmax_sel, ells, kk, theta, biases, noises, estimators_to_ignore)
    result = Optimizerkk.optimize(optversion, method = 'diff-ev', gtol = gtol, bounds = [0., 1.], noisebiasconstr = noisebiasconstr, fb = fb, inv_variance = invvariance, 
                     noiseparameter = 0.)

    #result.save_all(pathlib.Path('twocases')/lmax_directory, f'auto_fb_{fb}')
    #result.save(Optimizerkk.biases_selected, pathlib.Path('twocases')/lmax_directory, f'biases') 
    
    fnb_getter = lambda Opt, fb_val: Opt.get_f_n_b(Opt.ells_selected, Opt.theory_selected, Opt.theta_selected, Opt.biases_selected,
                              sum_biases_squared = False, bias_squared = False, fb = fb_val, inv_variance = False)
    
    f, n, b = fnb_getter(Optimizerkk, fb)
    ns = np.append(ns, n(result.x))
    bs = np.append(bs, b(result.x))
    fs = np.append(fs, f(result.x))
# Out:
# Doing for h3500s3000b2500
# Start optimization with diff-ev
# Doing for absbias
# Generation 0 has ChiSquare: 0.000364
# Generation 100 has ChiSquare: 0.000000
# Generation 200 has ChiSquare: 0.000000
# Generation 300 has ChiSquare: 0.000000
# Generation 400 has ChiSquare: 0.000000
# Generation 500 has ChiSquare: 0.000000
# Generation 600 has ChiSquare: 0.000000
# Generation 700 has ChiSquare: 0.000000
# Generation 800 has ChiSquare: 0.000000
# Generation 900 has ChiSquare: 0.000000
# Generation 1000 has ChiSquare: 0.000000
# Generation 1100 has ChiSquare: 0.000000
# Generation 1200 has ChiSquare: 0.000000
# Generation 1300 has ChiSquare: 0.000000
# Generation 1400 has ChiSquare: 0.000000
# Generation 1500 has ChiSquare: 0.000000
# Generation 1600 has ChiSquare: 0.000000
# Generation 1700 has ChiSquare: 0.000000
# Generation 1800 has ChiSquare: 0.000000
# Generation 1900 has ChiSquare: 0.000000
# Generation 2000 has ChiSquare: 0.000000
# Generation 2100 has ChiSquare: 0.000000
# STOP("ChangeOverGeneration with {'tolerance': 1e-11, 'generations': 1000}")
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 2119
#          Function evaluations: 357683
# Weights in columns [[-1.16933974  2.16933974]
#  [ 2.21967137 -1.21967137]
#  [ 0.06557799  0.93442201]
#  [ 1.22863171 -0.22863171]
#  [ 2.65896133 -1.65896133]
#  [-0.11610153  1.11610153]
#  [ 0.18253486  0.81746514]
#  [-0.85910929  1.85910929]]
# Sum [1. 1. 1. 1. 1. 1. 1. 1.]

# %%
ws, wbh, w = result.ws

a = np.c_[ws, wbh]
    
combinedn = Optimizerkk.get_bias_part(a, Optimizerkk.noises_selected)
combinedb = Optimizerkk.get_bias_part(a, Optimizerkk.biases_selected)

b = Optimizerkk.biases_selected
n = Optimizerkk.noises_selected

fig, ax = plt.subplots(nrows = 5, sharex = True)

kk = Optimizerkk.theory_selected

ells = Optimizerkk.ells_selected

ax[0].plot(ells, combinedb/kk, color = 'purple', label = 'Combined', marker = 'o')
ax[0].plot(ells, b[0, 0]/kk, color = 'red', label = 'S')
ax[0].plot(ells, b[1, 1]/kk, color = 'green', label = 'B')

ax[1].plot(ells, combinedn, color = 'purple', label = 'Combined', marker = 'o')
ax[1].plot(ells, n[0, 0], color = 'red', label = 'S')
ax[1].plot(ells, n[1, 1], color = 'green', label = 'B')


ax[2].plot(ells, ws, color = 'red', label = 'S')
ax[2].plot(ells, wbh, color = 'green', label = 'B')

ax[3].plot(ells, w, color = 'black')

ax[4].plot(ells, ws*w*ells, color = 'red', label = 'S')
ax[4].plot(ells, wbh*w*ells, color = 'green', label = 'B')

ax[4].set_xlabel('$L$')
ax[0].set_ylabel('$B$')
ax[1].set_ylabel('$N$')
ax[2].set_ylabel('$W$')
ax[3].set_ylabel('$W_L$')
ax[4].set_ylabel('$LWW_L$')
ax[0].set_xscale('log')
ax[0].legend(ncol = 4)

# %%
BB = np.rollaxis(b, 2, 0)

# %%
e = np.ones(2)

# %%
invB = np.linalg.inv(BB)

# %%
norms = np.einsum('i, ...ij, j -> ...', e, invB, e)
a = np.einsum('i, ...ij -> ...j', e, invB)/norms.reshape(8, 1)

# %%
a.flatten()
# Out:
# array([ 0.87242743,  0.12757257,  0.70879901,  0.29120099, -0.86572348,
#         1.86572348,  0.16614247,  0.83385753,  0.439462  ,  0.560538  ,
#         0.44384155,  0.55615845,  0.62001279,  0.37998721,  0.87831924,
#         0.12168076])

# %%
from mystic.penalty import linear_equality, quadratic_equality

import mystic.solvers as my

from mystic.monitors import VerboseMonitor

def constraint_eq(x):
    x = np.array(x)
    a = Optimizerkk.get_a(x, inv_variance = True)
    a[:, 1] = 1-a[:, 0]
    x = a.flatten()
    return x


def penalty1(x):
    x = np.array(x)
    b = x[-Optimizerkk.nbins:]
    res = Optimizerkk.integerate_discrete(b, Optimizerkk.ells_selected)
    return 1-res

k = 1e20

@quadratic_equality(condition=penalty1, k = k)
def penalty(x):
    return 0.0 

bounds = [0., 1.]

Ne = len(Optimizerkk.estimators)

dims = Ne+1

bnds = [(bounds[0], bounds[1]) for i in range(dims*Optimizerkk.nbins)]
bnds = tuple(bnds)

x0 = result.x


mon = VerboseMonitor(100)


def constraint_eq(x):
    x = np.array(x)
    x[1] = 1.-x[0]
    return x

for i in range(8):
    def functiontoopt(x):
        x = np.array(x)
        biasterm = np.einsum('ij..., i, j -> ...', abs(Optimizerkk.biases_selected)/Optimizerkk.theory_selected, x, x)
        return np.sqrt((biasterm[i])**2)

    x0 = np.array([0.5, 0.5])

    resultfromT = my.diffev(functiontoopt, x0, npop = 10, bounds = [(0, 1), (0, 1)], ftol = 1e-10, gtol = 1000, maxiter = 1024**3, 
                          maxfun = 1024**3, constraints = constraint_eq, full_output = False)
    print(resultfromT)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.008313
#          Iterations: 1049
#          Function evaluations: 10283
# [1.00908251e-16 1.00000000e+00]
# Optimization terminated successfully.
#          Current function value: 0.002147
#          Iterations: 1006
#          Function evaluations: 10056
# [0.00317486 0.99682514]
# Optimization terminated successfully.
#          Current function value: 0.001066
#          Iterations: 1011
#          Function evaluations: 10077
# [8.87113738e-06 9.99991129e-01]
# Optimization terminated successfully.
#          Current function value: 0.002475
#          Iterations: 1024
#          Function evaluations: 10185
# [9.99999946e-01 5.42444655e-08]
# Optimization terminated successfully.
#          Current function value: 0.005269
#          Iterations: 1042
#          Function evaluations: 10298
# [1.00000000e+00 3.50366403e-11]
# Optimization terminated successfully.
#          Current function value: 0.005369
#          Iterations: 1013
#          Function evaluations: 10125
# [0.99283823 0.00716177]
# Optimization terminated successfully.
#          Current function value: 0.014701
#          Iterations: 1065
#          Function evaluations: 10522
# [7.56820745e-17 1.00000000e+00]
# Optimization terminated successfully.
#          Current function value: 0.021514
#          Iterations: 1049
#          Function evaluations: 10448
# [3.29184122e-08 9.99999967e-01]

# %%
resultfromT[0].sum()
# Out:
# 1.0

# %%
functiontoopt(resultfromT[0])
# Out:
# 0.0021301014746883946

# %%
resultfromT[0]
# Out:
# array([4.05388716e-12, 1.00000000e+00])

# %%
a[:, 0]
# Out:
# array([ 0.87242743,  0.70879901, -0.86572348,  0.16614247,  0.439462  ,
#         0.44384155,  0.62001279,  0.87831924])

# %%
plt.plot(ells, a[:, 0], color = 'red', ls = '--')
plt.plot(ells, a[:, 1], color = 'green', ls = '--')

plt.plot(ells, ws, color = 'red', label = 'S')
plt.plot(ells, wbh, color = 'green', label = 'B')
plt.legend()

# %%
wbh
# Out:
# array([ 2.16933974, -1.21967137,  0.93442201, -0.22863171, -1.65896133,
#         1.11610153,  0.81746514,  1.85910929])
